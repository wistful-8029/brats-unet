# %%
import h5py
import os
import numpy as np
import SimpleITK as sitk
from tqdm import tqdm

os.getcwd()
# Out:
# '/home/yry08'

# %%
predict_path = '/mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/'

# %%
predict_path
# Out:
# '/mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/'

# %%
img_prefix = 'img'
pred_prefix = 'pred'

names = os.listdir(predict_path)

for name in tqdm(names):
    if img_prefix in name:
        old_name = predict_path + name
        # print(old_name)
        new_name = predict_path+name.split('.')[0] + '_flair.nii.gz'
        # print(new_name)

    if pred_prefix in name:
        old_name = predict_path + name
        print(old_name)
        new_name = predict_path+name.split('.')[0] + '_flair.nii.gz'
        print(new_name)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 378/378 [00:00<00:00, 187205.92it/s]
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/104_pred.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/104_pred_flair.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/01_pred.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/01_pred_flair.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/56_pred.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/56_pred_flair.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/66_pred.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/66_pred_flair.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/41_pred.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/41_pred_flair.nii.gz
# /mnt/sda3/yigedabuliu/lkq/brats-unet/predictions/unet/03_pred.nii.gz
# ...
